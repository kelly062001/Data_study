# %%
import pandas as pd 
import numpy as np

# %%
drama_reviews = pd.read_csv('./reviews.csv')

# %%
drama_reviews
# Out:
#                                 user_id                            title  \
# 0      c8ffdab3f2a338eeb54b265598dbbb55                    Sing My Crush
# 1      c8ffdab3f2a338eeb54b265598dbbb55               Happy Merry Ending
# 2      c8ffdab3f2a338eeb54b265598dbbb55        Duty After School: Part 2
# 3      c8ffdab3f2a338eeb54b265598dbbb55                   Our Dating Sim
# 4      c8ffdab3f2a338eeb54b265598dbbb55  The Director Who Buys Me Dinner
# ...                                 ...                              ...
# 10620  33bb7ae6e00a345c927f1b8e39594908                   Heart to Heart
# 10621  e5d4bbe315b03eb4878aa84d2f4fcff0                 Kill Me, Heal Me
# 10622  43aaace8631f36eda17a1880c7329a82                 Kill Me, Heal Me
# 10623  172b38a4599f3a649fe192fb967ce084                 Kill Me, Heal Me
# 10624  2ab12227bf5b3a39bcc82161ddfa5ea5                 Kill Me, Heal Me
#
#        story_score  acting_cast_score  music_score  rewatch_value_score  \
# ...

# %%
drama_title_list = drama_reviews['title'].unique()

# %%
len(drama_title_list)
# Out:
# 1279

# %%
drama_reviews_score = drama_reviews.groupby('title').mean()
drama_reviews_score
# Out:
#                                             story_score  acting_cast_score  \
# title
# 100 Days My Prince                             6.958333           8.625000
# 100% Era                                       8.375000           7.750000
# 109 Strange Things                             5.800000           6.500000
# 18 Again                                       7.708333           8.833333
# 187 cm Male Friend vs 155 cm Female Friend     7.000000           8.000000
# ...                                                 ...                ...
# Youtuber Class                                 7.833333           8.166667
# Yum Yum, How Tasty!                            3.000000           5.000000
# Yumi's Cells                                   8.708333           9.083333
# Yumi's Cells Season 2                          6.833333           8.208333
# Zombie Detective                               7.625000           8.666667
#
# ...

# %%
drama_reviews_score.sort_values(by='overall_score')
# Out:
#                                 story_score  acting_cast_score  music_score  \
# title
# I'm Sorry Kang Nam Goo             1.500000              2.500     1.000000
# Witch's Castle                     1.500000              1.500     1.000000
# Oh My Grace                        2.200000              2.900     4.700000
# 28 Faces of the Moon               1.750000              1.875     2.500000
# Woo Ri the Virgin                  1.958333              4.000     3.833333
# ...                                     ...                ...          ...
# Pale Moon                         10.000000             10.000    10.000000
# Poetry Story                      10.000000             10.000     9.500000
# My Mother Is a Daughter-In-Law    10.000000             10.000    10.000000
# Stranger Kim                      10.000000             10.000    10.000000
# Naughty Boy                       10.000000             10.000     9.500000
#
# ...

# %%
drama_reviews[drama_reviews['title']=="Yumi's Cells"].mean()
# Out:
# C:\Users\hyunj\AppData\Local\Temp/ipykernel_1896/1991591209.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   drama_reviews[drama_reviews['title']=="Yumi's Cells"].mean()
# story_score             8.708333
# acting_cast_score       9.083333
# music_score             8.541667
# rewatch_value_score     7.833333
# overall_score           8.750000
# n_helpful              19.416667
# dtype: float64

# %%
korean_drama = pd.read_csv('./korean_drama.csv')

# %%
korean_drama.rename(columns={'drama_name': 'title'}, inplace=True)

# %%
korean_drama['title'].unique()
# Out:
# array(['Sing My Crush', 'D.P. Season 2', 'Shadow Detective Season 2', ...,
#        'Iron Lady Cha', 'The Family Is Coming', 'Crow Building'],
#       dtype=object)

# %%
len(korean_drama['title'].unique())
# Out:
# 1752

# %%
korean_drama[korean_drama['title']=="Yumi's Cells"]
# Out:
#                             kdrama_id         title  year           director  \
# 406  dbd263bed8d8402797d1a7e87d26d3e2  Yumi's Cells  2021  ['Lee Sang Yeob']
#
#                                           screenwriter      country   type  \
# 406  ['Song Jae Jung', 'Kim Yoon Joo', 'Kim Kyung R...  South Korea  Drama
#
#      tot_eps  duration    start_dt      end_dt          aired_on    org_net  \
# 406       14    4200.0  2021-09-17  2021-10-30  Friday, Saturday  TVING tvN
#
#                   content_rt  \
# 406  13+ - Teens 13 or older
#
#                                               synopsis  rank  pop
# 406  Controlled by a complex network of cells, each...   650  245

# %%
drama_reviews[drama_reviews['title']=="Yumi's Cells"].append(korean_drama[korean_drama['drama_name']=="Yumi's Cells"])
# Out:
#                                user_id         title  story_score  \
# 575   1ab09f6dfcbc35a1920d86ccb009b64c  Yumi's Cells         10.0
# 1490  57f010032ba136f99d4f95befef7d00d  Yumi's Cells          5.0
# 3346  8c6432ec7e80375cb7315e6fad6609b8  Yumi's Cells          6.5
# 3544  9ec0d795c08f373abc1b6139f38fd2e8  Yumi's Cells          9.0
# 3619  e482f45fe91c3670917801eb5cc4f927  Yumi's Cells          9.0
# 4472  4fbf3ed2b9ef334db82047bed62f6760  Yumi's Cells          9.5
# 4556  d183c12d281e3e5bab7649d978d530a0  Yumi's Cells          8.5
# 5386  25d85e36a03533fa87dfaecdaf587f40  Yumi's Cells         10.0
# 5387  9b2a4c672e753bdea73a2e26d54dd4fc  Yumi's Cells         10.0
# 5388  0a88356c5f58330a88b3cc70c10f3a0a  Yumi's Cells          7.0
# 5390  842a7251f6543f62ad6c7d7c29750795  Yumi's Cells         10.0
# 5391  630d731ebba9389fa5f55a9ef26180bb  Yumi's Cells         10.0
# 406                                NaN           NaN          NaN
#
# ...
