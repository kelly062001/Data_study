# %%
import numpy as np
import pandas as pd

# %%
survey_data = pd.read_csv('./change_survey_data_8.19.csv')
df=pd.DataFrame(survey_data)
df=df.drop('Unnamed: 0', axis=1)
df
# Out:
#      frequency_findinginfo  search_volume_findinginfo  Anxiety  change_plan  \
# 0                        1                          2        4            0
# 1                        2                          3        4            0
# 2                        3                          2        3            0
# 3                        3                          4        5            1
# 4                        3                          3        2            0
# ..                     ...                        ...      ...          ...
# 295                      3                          5        4            1
# 296                      2                          4        2            0
# 297                      2                          3        3            0
# 298                      1                          2        4            0
# 299                      2                          3        4            1
#
#      effect_change_plan  selfdefence_item_search selfdefence_item_type  \
# 0                   NaN                        0           (검색해보지 않았다)
# 1                   3.0                        1                   경보기
# 2                   NaN                        0           (검색해보지 않았다)
# 3                   5.0                        1              호신용 스프레이
# 4                   3.0                        0           (검색해보지 않았다)
# ..                  ...                      ...                   ...
# 295                 1.0                        0           (검색해보지 않았다)
# 296                 2.0                        0           (검색해보지 않았다)
# 297                 NaN                        0           (검색해보지 않았다)
# 298                 1.0                        0           (검색해보지 않았다)
# 299                 5.0                        0           (검색해보지 않았다)
#
#      selfdefence_item_purchase  selfdefence_item_purchase_period  \
# 0                            0                               NaN
# 1                            0                               NaN
# 2                            0                               NaN
# 3                            0                               NaN
# 4                            0                               NaN
# ..                         ...                               ...
# 295                          0                               NaN
# 296                          1                              30.0
# 297                          0                               NaN
# 298                          0                               NaN
# 299                          0                               NaN
#
#      selfdefence_item_purchase_present  ...  selfdefence_item_friend  \
# 0                                    0  ...                        0
# 1                                    0  ...                        1
# 2                                    0  ...                        2
# 3                                    0  ...                        3
# 4                                    0  ...                        0
# ..                                 ...  ...                      ...
# 295                                  0  ...                        0
# 296                                  0  ...                        0
# 297                                  0  ...                        0
# 298                                  0  ...                        0
# 299                                  0  ...                        1
#
#      selfdefence_item_security  selfdefence_item_permission  \
# 0                            3                            0
# 1                            2                            0
# 2                            3                            1
# 3                            2                            1
# 4                            2                            2
# ..                         ...                          ...
# 295                          1                            2
# 296                          2                            0
# 297                          2                            0
# 298                          3                            0
# 299                          2                            0
#
#      selfdefence_item_self_defence  sex        age     residence job  \
# 0                                0    1         21       서울시 성북구   1
# 1                                2    1         24  경기도 고양시 일산서구   1
# 2                                2    1         22       강원도 원주시   1
# 3                                2    1         25   경기도 성남시 분당구   1
# 4                                2    0         25   경기도 성남시 수정구   1
# ..                             ...  ...        ...           ...  ..
# 295                              2    0         25   경기도 고양시 향동동   1
# 296                              0    1         22      인천시 미추홀구   1
# 297                              1    1         20           서초구   1
# 298                              2    0  20 (만 18)       서울시 구로구   1
# 299                              0    1         25        서울 강동구   1
#
#      have_children  household
# 0                0          0
# 1                0          1
# 2                0          1
# 3                0          1
# 4                0          1
# ..             ...        ...
# 295              0          1
# 296              0          1
# 297              0          1
# 298              0          1
# 299              0          1
#
# [300 rows x 21 columns]

# %%
print(type(df))
print(df.keys())
df.shape

X=df
y=
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index(['frequency_findinginfo', 'search_volume_findinginfo', 'Anxiety',
#        'change_plan', 'effect_change_plan', 'selfdefence_item_search',
#        'selfdefence_item_type', 'selfdefence_item_purchase',
#        'selfdefence_item_purchase_period', 'selfdefence_item_purchase_present',
#        'selfdefence_item_purchase_present_period', 'selfdefence_item_friend',
#        'selfdefence_item_security', 'selfdefence_item_permission',
#        'selfdefence_item_self_defence', 'sex', 'age', 'residence', 'job',
#        'have_children', 'household'],
#       dtype='object')
# (300, 21)

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error
