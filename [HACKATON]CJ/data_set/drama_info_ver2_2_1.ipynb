# %%
import pandas as pd

# %%
korea_drama = pd.read_csv('./drama_info_ver2_2_1.csv')

# %%
korea_drama
# Out:
#                      eng_title  kor_title  \
# 0                Sing My Crush       따라바람
# 1                D.P. Season 2     디피 시즌2
# 2    Shadow Detective Season 2    형사록 시즌2
# 3                    Celebrity      셀러브리티
# 4             Blue Temperature     파랑의 온도
# ..                         ...        ...
# 575          How Are You Bread     하와유브레드
# 576                 Money Game       머니게임
# 577            Winter Vacation       겨울방학
# 578      Dr. Romantic Season 2  낭만닥터 김사부2
# 579                      Touch         터치
#
#                                              genre             org_net  \
# 0          ['Music', 'Comedy', 'Romance', 'Youth']                 NaN
# 1                  ['Action', 'Military', 'Drama']             Netflix
# 2                             ['Mystery', 'Drama']        Disney+ Hulu
# 3                 ['Thriller', 'Mystery', 'Drama']             Netflix
# 4                             ['Romance', 'Youth']       Naver TV Cast
# ...
